# %%
import pandas as pd
df=pd.read_csv("C:\\Users\\LRS\\AppData\\Local\\Temp\\ab0fa1ff-ffb2-4e36-b439-f45f670323c2_seaborn-data-master.zip.3c2\\seaborn-data-master\\mpg.csv")
print(df)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
#this table shows the relationship between horsepower and mpg
#the higher the horsepower, the less mpg the vehicle has
print(df),
import matplotlib.pyplot as plt
import numpy as np
x=df['mpg'].tolist()
y=df['horsepower'].tolist()
xpoints = np.array([x])
ypoints = np.array([y])
plt.plot(x, y, 'o')
plt.show()
print(x,y)
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
#this table shows the relationship between the country of origin and the mpg\n",
#Japan has the highest mpg, Europe is second, and cars made in the USA have the lowest mpg\n",

print(df)
import matplotlib.pyplot as plt
import numpy as np
x=df['mpg'].tolist()
y=df['origin'].tolist()
xpoints = np.array([x]),
ypoints = np.array([y])
plt.bar(y,x )
plt.show()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...

# %%
#this table shows the relationship between the model year and mpg
#as cars get newer, they tend to have better mpg

import matplotlib.pyplot as plt
import numpy as np
x=df['mpg'].tolist()
y=df['model_year'].tolist()
    
xpoints = np.array([x])
ypoints = np.array([y])
plt.bar(y,x )
plt.show()

# %%
#this table shows the relationship between displacement and mpg\n",
#if displacement is larger, the car has lower mpg\n",

import matplotlib.pyplot as plt
import numpy as np
x=df['mpg'].tolist()
y=df['displacement'].tolist()
xpoints = np.array([x])
ypoints = np.array([y])
plt.bar(y,x )
plt.show()

# %%
#this table shows the relationship between the weight of a vehicle and the mpg\n",
#as cars become heavier they have mower mpg\n",
print(df)
import matplotlib.pyplot as plt
import numpy as np
x=df['mpg'].tolist()
y=df['weight'].tolist()
xpoints = np.array([x])
ypoints = np.array([y])
plt.bar(y,x )
plt.show()
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0       130.0    3504          12.0
# 1    15.0          8         350.0       165.0    3693          11.5
# 2    18.0          8         318.0       150.0    3436          11.0
# 3    16.0          8         304.0       150.0    3433          12.0
# 4    17.0          8         302.0       140.0    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 393  27.0          4         140.0        86.0    2790          15.6
# 394  44.0          4          97.0        52.0    2130          24.6
# 395  32.0          4         135.0        84.0    2295          11.6
# 396  28.0          4         120.0        79.0    2625          18.6
# 397  31.0          4         119.0        82.0    2720          19.4
#
#      model_year  origin                       name
# 0            70     usa  chevrolet chevelle malibu
# ...
